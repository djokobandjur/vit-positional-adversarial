# %%
# !nvidia-smi
import torch
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'Memory: {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB')
# Out:
# Tue Apr  7 05:34:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          Off |   00000000:04:00.0 Off |                    0 |
# | N/A   26C    P0             66W /  700W |       0MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# CUDA: True
# GPU: NVIDIA H100 80GB HBM3
# Memory: 85.0 GB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copy2('/content/drive/My Drive/pe_experiment/full_scale_experiment.py', '/content/')
shutil.copy2('/content/drive/My Drive/pe_experiment/cifar100_experiment.py', '/content/')
# Out:
# '/content/cifar100_experiment.py'

# %%
# !python /content/cifar100_experiment.py
# Out:
# Device: cuda
# 100% 169M/169M [00:04<00:00, 35.0MB/s]
# Train: 50000, Val: 10000
#
# ============================================================
#   PHASE 1: Training 12 models on CIFAR-100
# ============================================================
#
# ==================================================
#   LEARNED PE, seed=42
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   LEARNED PE, seed=123
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   LEARNED PE, seed=456
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   SINUSOIDAL PE, seed=42
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   SINUSOIDAL PE, seed=123
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   SINUSOIDAL PE, seed=456
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   ROPE PE, seed=42
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   ROPE PE, seed=123
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   ROPE PE, seed=456
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   ALIBI PE, seed=42
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   ALIBI PE, seed=123
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ==================================================
#   ALIBI PE, seed=456
# ==================================================
#   Already trained (300 epochs)! Skipping.
#
# ============================================================
#   PHASE 2: Adversarial attacks on all 12 models
# ============================================================
#
# ==================================================
#   ATTACK: LEARNED PE, seed=42
# ==================================================
#   Clean: 68.72%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 68.49% Δ= +0.23pp (5.3s)
#     ε=0.005  acc= 67.65% Δ= +1.07pp (5.1s)
#     ε=0.01   acc= 66.10% Δ= +2.62pp (5.1s)
#     ε=0.05   acc= 36.07% Δ=+32.65pp (5.1s)
#     ε=0.1    acc=  4.62% Δ=+64.10pp (5.1s)
#     ε=0.2    acc=  1.54% Δ=+67.18pp (5.1s)
#     ε=0.5    acc=  1.23% Δ=+67.49pp (5.1s)
#     ε=1.0    acc=  1.58% Δ=+67.14pp (5.1s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 68.48% Δ= +0.24pp (47.1s)
#     ε=0.005  acc= 67.48% Δ= +1.24pp (47.3s)
#     ε=0.01   acc= 65.50% Δ= +3.22pp (47.3s)
#     ε=0.05   acc=  4.49% Δ=+64.23pp (47.0s)
#     ε=0.1    acc=  1.39% Δ=+67.33pp (47.0s)
#     ε=0.2    acc=  1.07% Δ=+67.65pp (47.2s)
#     ε=0.5    acc=  1.00% Δ=+67.72pp (47.2s)
#     ε=1.0    acc=  1.00% Δ=+67.72pp (47.3s)
#
#   --- VTA ---
#     ε=0.001  acc= 68.67% Δ= +0.05pp (5.2s)
#     ε=0.005  acc= 68.55% Δ= +0.17pp (5.1s)
#     ε=0.01   acc= 68.45% Δ= +0.27pp (5.1s)
#     ε=0.05   acc= 67.00% Δ= +1.72pp (5.2s)
#     ε=0.1    acc= 64.89% Δ= +3.83pp (5.2s)
#     ε=0.2    acc= 56.30% Δ=+12.42pp (5.2s)
#     ε=0.5    acc= 14.63% Δ=+54.09pp (5.2s)
#     ε=1.0    acc=  2.35% Δ=+66.37pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: LEARNED PE, seed=123
# ==================================================
#   Clean: 68.07%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 67.86% Δ= +0.21pp (5.1s)
#     ε=0.005  acc= 66.77% Δ= +1.30pp (5.1s)
#     ε=0.01   acc= 65.55% Δ= +2.52pp (5.1s)
#     ε=0.05   acc= 32.14% Δ=+35.93pp (5.1s)
#     ε=0.1    acc=  5.25% Δ=+62.82pp (5.1s)
#     ε=0.2    acc=  1.11% Δ=+66.96pp (5.1s)
#     ε=0.5    acc=  1.16% Δ=+66.91pp (5.1s)
#     ε=1.0    acc=  1.03% Δ=+67.04pp (5.1s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 67.84% Δ= +0.23pp (47.2s)
#     ε=0.005  acc= 66.54% Δ= +1.53pp (47.2s)
#     ε=0.01   acc= 64.94% Δ= +3.13pp (47.0s)
#     ε=0.05   acc=  7.12% Δ=+60.95pp (47.0s)
#     ε=0.1    acc=  1.49% Δ=+66.58pp (47.0s)
#     ε=0.2    acc=  1.02% Δ=+67.05pp (47.0s)
#     ε=0.5    acc=  1.00% Δ=+67.07pp (47.0s)
#     ε=1.0    acc=  1.00% Δ=+67.07pp (47.0s)
#
#   --- VTA ---
#     ε=0.001  acc= 68.07% Δ= +0.00pp (5.1s)
#     ε=0.005  acc= 67.86% Δ= +0.21pp (5.2s)
#     ε=0.01   acc= 67.57% Δ= +0.50pp (5.2s)
#     ε=0.05   acc= 64.96% Δ= +3.11pp (5.2s)
#     ε=0.1    acc= 58.33% Δ= +9.74pp (5.2s)
#     ε=0.2    acc= 33.48% Δ=+34.59pp (5.2s)
#     ε=0.5    acc=  2.99% Δ=+65.08pp (5.2s)
#     ε=1.0    acc=  1.27% Δ=+66.80pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: LEARNED PE, seed=456
# ==================================================
#   Clean: 68.04%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 67.82% Δ= +0.22pp (5.1s)
#     ε=0.005  acc= 66.89% Δ= +1.15pp (5.1s)
#     ε=0.01   acc= 65.72% Δ= +2.32pp (5.1s)
#     ε=0.05   acc= 33.50% Δ=+34.54pp (5.1s)
#     ε=0.1    acc=  5.91% Δ=+62.13pp (5.1s)
#     ε=0.2    acc=  2.15% Δ=+65.89pp (5.1s)
#     ε=0.5    acc=  1.27% Δ=+66.77pp (5.1s)
#     ε=1.0    acc=  1.00% Δ=+67.04pp (5.1s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 67.83% Δ= +0.21pp (47.3s)
#     ε=0.005  acc= 66.74% Δ= +1.30pp (47.3s)
#     ε=0.01   acc= 64.99% Δ= +3.05pp (47.3s)
#     ε=0.05   acc=  9.09% Δ=+58.95pp (47.3s)
#     ε=0.1    acc=  1.21% Δ=+66.83pp (47.3s)
#     ε=0.2    acc=  1.00% Δ=+67.04pp (47.3s)
#     ε=0.5    acc=  1.00% Δ=+67.04pp (47.3s)
#     ε=1.0    acc=  1.00% Δ=+67.04pp (47.3s)
#
#   --- VTA ---
#     ε=0.001  acc= 68.03% Δ= +0.01pp (5.2s)
#     ε=0.005  acc= 67.86% Δ= +0.18pp (5.2s)
#     ε=0.01   acc= 67.56% Δ= +0.48pp (5.2s)
#     ε=0.05   acc= 65.48% Δ= +2.56pp (5.2s)
#     ε=0.1    acc= 60.41% Δ= +7.63pp (5.2s)
#     ε=0.2    acc= 41.49% Δ=+26.55pp (5.2s)
#     ε=0.5    acc=  5.13% Δ=+62.91pp (5.2s)
#     ε=1.0    acc=  1.79% Δ=+66.25pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: SINUSOIDAL PE, seed=42
# ==================================================
#   Clean: 67.40%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 67.30% Δ= +0.10pp (5.1s)
#     ε=0.005  acc= 67.10% Δ= +0.30pp (5.1s)
#     ε=0.01   acc= 66.53% Δ= +0.87pp (5.1s)
#     ε=0.05   acc= 61.27% Δ= +6.13pp (5.1s)
#     ε=0.1    acc= 45.89% Δ=+21.51pp (5.1s)
#     ε=0.2    acc=  4.62% Δ=+62.78pp (5.1s)
#     ε=0.5    acc=  1.74% Δ=+65.66pp (5.1s)
#     ε=1.0    acc=  1.45% Δ=+65.95pp (5.1s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 67.31% Δ= +0.09pp (47.3s)
#     ε=0.005  acc= 67.08% Δ= +0.32pp (47.3s)
#     ε=0.01   acc= 66.54% Δ= +0.86pp (47.4s)
#     ε=0.05   acc= 60.51% Δ= +6.89pp (47.0s)
#     ε=0.1    acc= 43.08% Δ=+24.32pp (47.0s)
#     ε=0.2    acc=  2.99% Δ=+64.41pp (47.0s)
#     ε=0.5    acc=  1.00% Δ=+66.40pp (47.0s)
#     ε=1.0    acc=  1.00% Δ=+66.40pp (47.0s)
#
#   --- VTA ---
#     ε=0.001  acc= 67.38% Δ= +0.02pp (5.2s)
#     ε=0.005  acc= 67.29% Δ= +0.11pp (5.2s)
#     ε=0.01   acc= 67.11% Δ= +0.29pp (5.2s)
#     ε=0.05   acc= 66.24% Δ= +1.16pp (5.2s)
#     ε=0.1    acc= 64.92% Δ= +2.48pp (5.2s)
#     ε=0.2    acc= 61.85% Δ= +5.55pp (5.2s)
#     ε=0.5    acc= 39.78% Δ=+27.62pp (5.2s)
#     ε=1.0    acc=  2.01% Δ=+65.39pp (5.1s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: SINUSOIDAL PE, seed=123
# ==================================================
#   Clean: 66.41%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 66.38% Δ= +0.03pp (5.3s)
#     ε=0.005  acc= 66.06% Δ= +0.35pp (5.1s)
#     ε=0.01   acc= 65.56% Δ= +0.85pp (5.1s)
#     ε=0.05   acc= 60.43% Δ= +5.98pp (5.1s)
#     ε=0.1    acc= 47.63% Δ=+18.78pp (5.1s)
#     ε=0.2    acc= 13.39% Δ=+53.02pp (5.1s)
#     ε=0.5    acc=  1.49% Δ=+64.92pp (5.1s)
#     ε=1.0    acc=  1.41% Δ=+65.00pp (5.1s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 66.38% Δ= +0.03pp (47.3s)
#     ε=0.005  acc= 66.05% Δ= +0.36pp (47.3s)
#     ε=0.01   acc= 65.53% Δ= +0.88pp (47.1s)
#     ε=0.05   acc= 59.98% Δ= +6.43pp (47.0s)
#     ε=0.1    acc= 44.90% Δ=+21.51pp (47.0s)
#     ε=0.2    acc=  5.91% Δ=+60.50pp (47.0s)
#     ε=0.5    acc=  1.00% Δ=+65.41pp (47.0s)
#     ε=1.0    acc=  1.00% Δ=+65.41pp (47.0s)
#
#   --- VTA ---
#     ε=0.001  acc= 66.40% Δ= +0.01pp (5.1s)
#     ε=0.005  acc= 66.37% Δ= +0.04pp (5.2s)
#     ε=0.01   acc= 66.31% Δ= +0.10pp (5.1s)
#     ε=0.05   acc= 65.42% Δ= +0.99pp (5.2s)
#     ε=0.1    acc= 64.35% Δ= +2.06pp (5.2s)
#     ε=0.2    acc= 61.89% Δ= +4.52pp (5.2s)
#     ε=0.5    acc= 41.57% Δ=+24.84pp (5.2s)
#     ε=1.0    acc=  4.23% Δ=+62.18pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: SINUSOIDAL PE, seed=456
# ==================================================
#   Clean: 66.95%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 66.85% Δ= +0.10pp (5.1s)
#     ε=0.005  acc= 66.50% Δ= +0.45pp (5.1s)
#     ε=0.01   acc= 66.00% Δ= +0.95pp (5.1s)
#     ε=0.05   acc= 60.19% Δ= +6.76pp (5.1s)
#     ε=0.1    acc= 45.91% Δ=+21.04pp (5.1s)
#     ε=0.2    acc=  9.12% Δ=+57.83pp (5.1s)
#     ε=0.5    acc=  1.22% Δ=+65.73pp (5.1s)
#     ε=1.0    acc=  1.00% Δ=+65.95pp (5.1s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 66.84% Δ= +0.11pp (47.3s)
#     ε=0.005  acc= 66.49% Δ= +0.46pp (47.3s)
#     ε=0.01   acc= 65.99% Δ= +0.96pp (47.3s)
#     ε=0.05   acc= 59.66% Δ= +7.29pp (47.3s)
#     ε=0.1    acc= 41.35% Δ=+25.60pp (47.3s)
#     ε=0.2    acc=  3.98% Δ=+62.97pp (47.3s)
#     ε=0.5    acc=  1.12% Δ=+65.83pp (47.3s)
#     ε=1.0    acc=  1.00% Δ=+65.95pp (47.3s)
#
#   --- VTA ---
#     ε=0.001  acc= 66.94% Δ= +0.01pp (5.2s)
#     ε=0.005  acc= 66.85% Δ= +0.10pp (5.2s)
#     ε=0.01   acc= 66.78% Δ= +0.17pp (5.2s)
#     ε=0.05   acc= 65.93% Δ= +1.02pp (5.2s)
#     ε=0.1    acc= 64.58% Δ= +2.37pp (5.2s)
#     ε=0.2    acc= 61.56% Δ= +5.39pp (5.2s)
#     ε=0.5    acc= 41.51% Δ=+25.44pp (5.2s)
#     ε=1.0    acc=  2.79% Δ=+64.16pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: ROPE PE, seed=42
# ==================================================
#   Clean: 73.10%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 73.08% Δ= +0.02pp (5.5s)
#     ε=0.005  acc= 73.08% Δ= +0.02pp (5.5s)
#     ε=0.01   acc= 73.06% Δ= +0.04pp (5.5s)
#     ε=0.05   acc= 72.93% Δ= +0.17pp (5.5s)
#     ε=0.1    acc= 72.81% Δ= +0.29pp (5.5s)
#     ε=0.2    acc= 72.50% Δ= +0.60pp (5.5s)
#     ε=0.5    acc= 71.66% Δ= +1.44pp (5.5s)
#     ε=1.0    acc= 70.70% Δ= +2.40pp (5.5s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 73.08% Δ= +0.02pp (50.4s)
#     ε=0.005  acc= 73.08% Δ= +0.02pp (50.4s)
#     ε=0.01   acc= 73.07% Δ= +0.03pp (50.4s)
#     ε=0.05   acc= 72.93% Δ= +0.17pp (50.4s)
#     ε=0.1    acc= 72.81% Δ= +0.29pp (50.4s)
#     ε=0.2    acc= 72.42% Δ= +0.68pp (50.4s)
#     ε=0.5    acc= 71.70% Δ= +1.40pp (50.4s)
#     ε=1.0    acc= 70.28% Δ= +2.82pp (50.4s)
#
#   --- VTA ---
#     ε=0.001  acc= 73.09% Δ= +0.01pp (5.5s)
#     ε=0.005  acc= 73.07% Δ= +0.03pp (5.5s)
#     ε=0.01   acc= 73.06% Δ= +0.04pp (5.5s)
#     ε=0.05   acc= 72.95% Δ= +0.15pp (5.5s)
#     ε=0.1    acc= 72.79% Δ= +0.31pp (5.5s)
#     ε=0.2    acc= 72.47% Δ= +0.63pp (5.5s)
#     ε=0.5    acc= 71.62% Δ= +1.48pp (5.5s)
#     ε=1.0    acc= 70.33% Δ= +2.77pp (5.5s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: ROPE PE, seed=123
# ==================================================
#   Clean: 73.35%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 73.36% Δ= -0.01pp (5.5s)
#     ε=0.005  acc= 73.35% Δ= +0.00pp (5.5s)
#     ε=0.01   acc= 73.32% Δ= +0.03pp (5.5s)
#     ε=0.05   acc= 73.19% Δ= +0.16pp (5.5s)
#     ε=0.1    acc= 73.07% Δ= +0.28pp (5.5s)
#     ε=0.2    acc= 72.66% Δ= +0.69pp (5.5s)
#     ε=0.5    acc= 71.67% Δ= +1.68pp (5.5s)
#     ε=1.0    acc= 70.43% Δ= +2.92pp (5.5s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 73.36% Δ= -0.01pp (50.4s)
#     ε=0.005  acc= 73.35% Δ= +0.00pp (50.4s)
#     ε=0.01   acc= 73.32% Δ= +0.03pp (50.4s)
#     ε=0.05   acc= 73.20% Δ= +0.15pp (50.4s)
#     ε=0.1    acc= 73.02% Δ= +0.33pp (50.4s)
#     ε=0.2    acc= 72.67% Δ= +0.68pp (50.4s)
#     ε=0.5    acc= 71.69% Δ= +1.66pp (50.4s)
#     ε=1.0    acc= 70.32% Δ= +3.03pp (50.4s)
#
#   --- VTA ---
#     ε=0.001  acc= 73.36% Δ= -0.01pp (5.5s)
#     ε=0.005  acc= 73.35% Δ= +0.00pp (5.5s)
#     ε=0.01   acc= 73.35% Δ= +0.00pp (5.5s)
#     ε=0.05   acc= 73.22% Δ= +0.13pp (5.5s)
#     ε=0.1    acc= 73.04% Δ= +0.31pp (5.5s)
#     ε=0.2    acc= 72.65% Δ= +0.70pp (5.5s)
#     ε=0.5    acc= 71.65% Δ= +1.70pp (5.5s)
#     ε=1.0    acc= 70.14% Δ= +3.21pp (5.5s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: ROPE PE, seed=456
# ==================================================
#   Clean: 73.45%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 73.45% Δ= +0.00pp (5.5s)
#     ε=0.005  acc= 73.45% Δ= +0.00pp (5.5s)
#     ε=0.01   acc= 73.46% Δ= -0.01pp (5.5s)
#     ε=0.05   acc= 73.32% Δ= +0.13pp (5.5s)
#     ε=0.1    acc= 73.22% Δ= +0.23pp (5.5s)
#     ε=0.2    acc= 72.81% Δ= +0.64pp (5.5s)
#     ε=0.5    acc= 71.90% Δ= +1.55pp (5.5s)
#     ε=1.0    acc= 70.70% Δ= +2.75pp (5.5s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 73.45% Δ= +0.00pp (50.4s)
#     ε=0.005  acc= 73.45% Δ= +0.00pp (50.4s)
#     ε=0.01   acc= 73.45% Δ= +0.00pp (50.4s)
#     ε=0.05   acc= 73.32% Δ= +0.13pp (50.4s)
#     ε=0.1    acc= 73.21% Δ= +0.24pp (50.4s)
#     ε=0.2    acc= 72.79% Δ= +0.66pp (50.4s)
#     ε=0.5    acc= 71.80% Δ= +1.65pp (50.4s)
#     ε=1.0    acc= 70.32% Δ= +3.13pp (50.4s)
#
#   --- VTA ---
#     ε=0.001  acc= 73.45% Δ= +0.00pp (5.5s)
#     ε=0.005  acc= 73.47% Δ= -0.02pp (5.5s)
#     ε=0.01   acc= 73.45% Δ= +0.00pp (5.5s)
#     ε=0.05   acc= 73.30% Δ= +0.15pp (5.5s)
#     ε=0.1    acc= 73.16% Δ= +0.29pp (5.5s)
#     ε=0.2    acc= 72.74% Δ= +0.71pp (5.5s)
#     ε=0.5    acc= 71.78% Δ= +1.67pp (5.5s)
#     ε=1.0    acc= 70.31% Δ= +3.14pp (5.5s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: ALIBI PE, seed=42
# ==================================================
#   Clean: 67.39%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 67.41% Δ= -0.02pp (5.3s)
#     ε=0.005  acc= 67.38% Δ= +0.01pp (5.3s)
#     ε=0.01   acc= 67.34% Δ= +0.05pp (5.2s)
#     ε=0.05   acc= 66.83% Δ= +0.56pp (5.2s)
#     ε=0.1    acc= 65.90% Δ= +1.49pp (5.2s)
#     ε=0.2    acc= 63.55% Δ= +3.84pp (5.2s)
#     ε=0.5    acc= 56.52% Δ=+10.87pp (5.2s)
#     ε=1.0    acc= 46.06% Δ=+21.33pp (5.2s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 67.41% Δ= -0.02pp (47.4s)
#     ε=0.005  acc= 67.38% Δ= +0.01pp (47.4s)
#     ε=0.01   acc= 67.34% Δ= +0.05pp (47.3s)
#     ε=0.05   acc= 66.83% Δ= +0.56pp (47.3s)
#     ε=0.1    acc= 65.90% Δ= +1.49pp (47.3s)
#     ε=0.2    acc= 41.49% Δ=+25.90pp (47.3s)
#     ε=0.5    acc= 33.13% Δ=+34.26pp (47.3s)
#     ε=1.0    acc= 24.18% Δ=+43.21pp (47.3s)
#
#   --- VTA ---
#     ε=0.001  acc= 67.36% Δ= +0.03pp (5.1s)
#     ε=0.005  acc= 67.33% Δ= +0.06pp (5.1s)
#     ε=0.01   acc= 67.26% Δ= +0.13pp (5.1s)
#     ε=0.05   acc= 66.45% Δ= +0.94pp (5.2s)
#     ε=0.1    acc= 60.98% Δ= +6.41pp (5.1s)
#     ε=0.2    acc= 40.61% Δ=+26.78pp (5.2s)
#     ε=0.5    acc= 31.23% Δ=+36.16pp (5.2s)
#     ε=1.0    acc= 24.18% Δ=+43.21pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: ALIBI PE, seed=123
# ==================================================
#   Clean: 68.16%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 68.17% Δ= -0.01pp (5.1s)
#     ε=0.005  acc= 68.19% Δ= -0.03pp (5.1s)
#     ε=0.01   acc= 68.09% Δ= +0.07pp (5.1s)
#     ε=0.05   acc= 67.84% Δ= +0.32pp (5.1s)
#     ε=0.1    acc= 67.24% Δ= +0.92pp (5.1s)
#     ε=0.2    acc= 65.93% Δ= +2.23pp (5.1s)
#     ε=0.5    acc= 60.30% Δ= +7.86pp (5.2s)
#     ε=1.0    acc= 46.94% Δ=+21.22pp (5.2s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 68.17% Δ= -0.01pp (47.6s)
#     ε=0.005  acc= 68.19% Δ= -0.03pp (47.3s)
#     ε=0.01   acc= 68.09% Δ= +0.07pp (47.3s)
#     ε=0.05   acc= 67.84% Δ= +0.32pp (47.3s)
#     ε=0.1    acc= 65.21% Δ= +2.95pp (47.5s)
#     ε=0.2    acc= 51.46% Δ=+16.70pp (47.3s)
#     ε=0.5    acc= 33.86% Δ=+34.30pp (47.3s)
#     ε=1.0    acc= 22.45% Δ=+45.71pp (47.3s)
#
#   --- VTA ---
#     ε=0.001  acc= 68.18% Δ= -0.02pp (5.1s)
#     ε=0.005  acc= 68.11% Δ= +0.05pp (5.1s)
#     ε=0.01   acc= 68.02% Δ= +0.14pp (5.1s)
#     ε=0.05   acc= 67.21% Δ= +0.95pp (5.1s)
#     ε=0.1    acc= 63.26% Δ= +4.90pp (5.2s)
#     ε=0.2    acc= 46.52% Δ=+21.64pp (5.2s)
#     ε=0.5    acc= 33.86% Δ=+34.30pp (5.2s)
#     ε=1.0    acc= 22.45% Δ=+45.71pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ==================================================
#   ATTACK: ALIBI PE, seed=456
# ==================================================
#   Clean: 67.42%
#
#   --- FGSM-PE ---
#     ε=0.001  acc= 67.42% Δ= +0.00pp (5.1s)
#     ε=0.005  acc= 67.28% Δ= +0.14pp (5.1s)
#     ε=0.01   acc= 67.23% Δ= +0.19pp (5.1s)
#     ε=0.05   acc= 66.58% Δ= +0.84pp (5.2s)
#     ε=0.1    acc= 64.65% Δ= +2.77pp (5.2s)
#     ε=0.2    acc= 58.89% Δ= +8.53pp (5.2s)
#     ε=0.5    acc= 46.15% Δ=+21.27pp (5.2s)
#     ε=1.0    acc= 29.96% Δ=+37.46pp (5.2s)
#
#   --- PGD-PE ---
#     ε=0.001  acc= 67.42% Δ= +0.00pp (47.6s)
#     ε=0.005  acc= 67.28% Δ= +0.14pp (47.6s)
#     ε=0.01   acc= 67.23% Δ= +0.19pp (47.5s)
#     ε=0.05   acc= 66.58% Δ= +0.84pp (47.5s)
#     ε=0.1    acc= 64.65% Δ= +2.77pp (47.6s)
#     ε=0.2    acc= 58.89% Δ= +8.53pp (47.6s)
#     ε=0.5    acc= 38.01% Δ=+29.41pp (47.6s)
#     ε=1.0    acc= 22.42% Δ=+45.00pp (47.6s)
#
#   --- VTA ---
#     ε=0.001  acc= 67.41% Δ= +0.01pp (5.2s)
#     ε=0.005  acc= 67.32% Δ= +0.10pp (5.2s)
#     ε=0.01   acc= 67.19% Δ= +0.23pp (5.2s)
#     ε=0.05   acc= 66.34% Δ= +1.08pp (5.2s)
#     ε=0.1    acc= 61.48% Δ= +5.94pp (5.2s)
#     ε=0.2    acc= 44.28% Δ=+23.14pp (5.2s)
#     ε=0.5    acc= 32.40% Δ=+35.02pp (5.2s)
#     ε=1.0    acc= 22.42% Δ=+45.00pp (5.2s)
#
#   ✅ Saved to /content/drive/My Drive/pe_experiment/results_cifar100/adversarial_pe_results_cifar100.json
#
# ============================================================
#   ALL DONE!
# ============================================================
